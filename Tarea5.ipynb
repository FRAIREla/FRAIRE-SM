# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Graficar las siguientes funciones f(x). Determina el dominio a partir de la función:

# %%
x = np.linspace(-4,4, 500)

# %%
d1 = x**2 - 4*x + 2
d2 = np.sin(3*x)
d3 = np.exp(2*x)-3
d4 = np.sqrt(x**2 - 4)
d5 = np.cos(x + np.pi/4)
# Out:
# C:\Users\Eduardo\AppData\Local\Temp\ipykernel_4732\1874273201.py:4: RuntimeWarning: invalid value encountered in sqrt
#   d4 = np.sqrt(x**2 - 4)

# %%
plt.figure(figsize=(6,6))
plt.plot(x,d1)
plt.title("ecuacion 1")
plt.xlabel("eje x")
plt.ylabel("eje y")
plt.grid()

# %%
plt.figure(figsize=(6,6))
plt.plot(x,d2)
plt.title("ecuacion 2")
plt.xlabel("eje x")
plt.ylabel("eje y")
plt.grid()

# %%
plt.figure(figsize=(6,6))
plt.plot(x,d3)
plt.title("ecuacion 3")
plt.xlabel("eje x")
plt.ylabel("eje y")
plt.grid()

# %%
plt.figure(figsize=(6,6))
plt.plot(x,d4)
plt.title("ecuacion 4")
plt.xlabel("eje x")
plt.ylabel("eje y")
plt.grid()

# %%
plt.figure(figsize=(6,6))
plt.plot(x,d5)
plt.title("ecuacion 5")
plt.xlabel("eje x")
plt.ylabel("eje y")
plt.grid()

# %%
y1_1=2*x+1
y2_1=-x+4
y3_1=x**2

# %%
y1_2=np.sin(x)
y2_2=np.cos(x)

# %%
plt.figure(figsize=(6,6))
plt.plot(x,y1_1)
plt.plot(x,y2_1)
plt.plot(x,y3_1)
plt.title("GRUPO A")
plt.xlabel("eje x")
plt.ylabel("eje y")
plt.grid()

# %%
plt.figure(figsize=(6,6))
plt.plot(x,y1_2)
plt.plot(x,y2_2)
plt.title("GRUPO B")
plt.ylabel("eje y")
plt.xlabel("eje x")
plt.grid()

# %%
def FUNCIÓN(x1,x2,n,a,b,k):
    x = np.linspace(x1,x2,n)
    alpha = np.linspace (a,b,k)

    for alpha in alpha:
        y = np.sin(alpha*x)
        plt.plot(x,y)

plt.ylabel("EJE Y")
plt.xlabel("EJE X")
plt.grid()

FUNCIÓN(0, np.pi*2, 1000, 1, 3, 3)
